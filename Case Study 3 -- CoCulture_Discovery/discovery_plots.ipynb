# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io as sio
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import scipy.signal as sig
import matplotlib
from matplotlib.ticker import ScalarFormatter
import numpy as np
import pylab as pl

# %%
val = sio.loadmat('validations.mat')
predicted_list = [val.get('y1p_list')[0,0], val.get('y2p_list')[0,0], val.get('y3p_list')[0,0],
                  val.get('y4p_list')[0,0],val.get('y5p_list')[0,0]]

true_list = [val.get('y1t_list')[0,0], val.get('y2t_list')[0,0], val.get('y3t_list')[0,0],
             val.get('y4t_list')[0,0], val.get('y5t_list')[0,0]]

tlist = [val.get('time_list')]
times = tlist[0][0][0][0]
predicted_minus = [val.get('y1minus'), val.get('y2minus'), val.get('y3minus'), val.get('y4minus'), val.get('y5minus')]
predicted_plus  = [val.get('y1plus'), val.get('y2plus'), val.get('y3plus'), val.get('y4plus'), val.get('y5plus')]

# %%
plt.rcParams['axes.linewidth'] = 1.5

# %%
len(times)
# Out:
# 40

# %%
#c1in_val= val.get('inputs_seq_DR')[0]
#SFrate_val= val.get('inputs_seq_SF')[0]
plt.rcParams['text.usetex'] = True

# %%
#plt.style.use('default')
colorlist = ['red','#2DDE4F','#4F2DDE','orange','purple']


plt.figure(1,dpi=500)
alphaval=0.5
alphavlines = 0.4
marksize = 5
lwi = 2
plt.plot(times,true_list[0],'s',markersize=marksize,color='k',alpha=0.7)

plt.plot(times,predicted_list[0],'-o',color=colorlist[0],linewidth=lwi,alpha=0.5,markeredgecolor='k')

#plt.plot(times,predicted_minus[0],color='k',linestyle='-',alpha=1,linewidth=2)
#plt.plot(times,predicted_plus[0],color='k',linestyle='-',alpha=1,linewidth=2)
#plt.fill_between(times.reshape(len(times),),predicted_minus[0].reshape(len(times),),
#                 predicted_plus[0].reshape(len(times),),alpha=alphaval,color=colorlist[0])
plt.vlines(times,predicted_minus[0],predicted_plus[0], linestyles='solid',color=colorlist[0], alpha=alphavlines)
    
plt.xlim([0,8])
plt.xlabel(r'$t \; (hr)$', fontsize=25)
plt.ylabel(r'$C_0 \; (g/L)$',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.grid(b=True, which='major', color='k', linestyle='-')
#plt.grid(b=True, which='both', color='k', linestyle='-',linewidth=0.3)


plt.figure(2,dpi=500)
alphaval=0.5
marksize = 5
plt.plot(times,true_list[1],'s',markersize=marksize,color='k',alpha=0.7)

plt.plot(times,predicted_list[1],'-o',color=colorlist[1],linewidth=lwi,alpha=0.8,markeredgecolor='k')
#plt.plot(times,predicted_minus[0],color='k',linestyle='-',alpha=1,linewidth=2)
#plt.plot(times,predicted_plus[0],color='k',linestyle='-',alpha=1,linewidth=2)
#plt.fill_between(times.reshape(len(times),),predicted_minus[0].reshape(len(times),),
#                 predicted_plus[0].reshape(len(times),),alpha=alphaval,color=colorlist[0])
plt.vlines(times,predicted_minus[1],predicted_plus[1], linestyles='solid',color=colorlist[1], alpha=alphavlines)
    
plt.xlim([0,8])
plt.xlabel(r'$t (hr)$', fontsize=25)
plt.ylabel(r'$C_1 \,(g/L)$',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)


plt.figure(3,dpi=400)
alphaval=0.5
marksize = 5
plt.plot(times,true_list[2],'s',markersize=marksize,color='k',alpha=0.7)

plt.plot(times,predicted_list[2],'-o',color=colorlist[2],linewidth=lwi,alpha=0.8,markeredgecolor='k')
plt.vlines(times,predicted_minus[2],predicted_plus[2], linestyles='solid',color=colorlist[2], alpha=alphavlines) 
plt.xlim([0,8])
plt.xlabel(r'$t (hr)$', fontsize=25)
plt.ylabel(r'$C_2 \,(g/L)$',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)


# plt.figure(4,dpi=500)
# alphaval=0.5
# marksize = 5
# plt.semilogy(times,predicted_list[3],'-o',color=colorlist[3],linewidth=lwi,alpha=0.8,markeredgecolor='k')
# plt.semilogy(times,true_list[3],'s',markersize=marksize,color='k')
# #plt.plot(times,predicted_minus[0],color='k',linestyle='-',alpha=1,linewidth=2)
# #plt.plot(times,predicted_plus[0],color='k',linestyle='-',alpha=1,linewidth=2)
# #plt.fill_between(times.reshape(len(times),),predicted_minus[0].reshape(len(times),),
# #                 predicted_plus[0].reshape(len(times),),alpha=alphaval,color=colorlist[0])
# plt.vlines(times,predicted_minus[3],predicted_plus[3], linestyles='solid',color=colorlist[3], alpha=0.75)
    
# plt.xlim([0,8])
# plt.xlabel(r'$t (hr)$', fontsize=25)
# plt.ylabel(r'$C_2 \,(g/L)$',fontsize=25)
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)



# plt.figure(4,dpi=500)
# alphaval=0.5
# marksize = 5
# plt.semilogy(times,predicted_list[4],'-o',color=colorlist[4],linewidth=lwi,alpha=0.8,markeredgecolor='k')
# plt.semilogy(times,true_list[4],'s',markersize=marksize,color='k')
# #plt.plot(times,predicted_minus[0],color='k',linestyle='-',alpha=1,linewidth=2)
# #plt.plot(times,predicted_plus[0],color='k',linestyle='-',alpha=1,linewidth=2)
# #plt.fill_between(times.reshape(len(times),),predicted_minus[0].reshape(len(times),),
# #                 predicted_plus[0].reshape(len(times),),alpha=alphaval,color=colorlist[0])
# plt.vlines(times,predicted_minus[4],predicted_plus[4], linestyles='solid',color=colorlist[4], alpha=0.75)
    
# plt.xlim([0,8])
# plt.xlabel(r'$Time (hr)$', fontsize=25)
# plt.ylabel(r'$N_2 \,(g/L)$',fontsize=25)
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)



fig,ax = plt.subplots(dpi=500)
# make a plot
ax.plot(times,true_list[3],'s',markersize=marksize,color='k',alpha=0.7)

ax.plot(times,predicted_list[3],'-o',color=colorlist[3],linewidth=lwi,alpha=0.8,markeredgecolor='k')
plt.vlines(times,predicted_minus[3],predicted_plus[3], linestyles='solid',color=colorlist[3], alpha=alphavlines)
# set x-axis label
ax.set_xlabel(r'$t (hr)$', fontsize=25)
# set y-axis label
ax.set_ylabel(r'$N_1 \,(g/L)$',color=colorlist[3],fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)


# twin object for two different y-axis on the sample plot

ax2=ax.twinx()
ax2.plot(times,true_list[4],'^',markersize=marksize,color='k',alpha=0.7)

ax2.plot(times,predicted_list[4],'-o',color=colorlist[4],linewidth=lwi,alpha=0.8,markeredgecolor='k')
plt.vlines(times,predicted_minus[4],predicted_plus[4], linestyles='solid',color=colorlist[4], alpha=0.4)
ax.set_xlabel(r'$t\; (hr)$', fontsize=25)
# set y-axis label
ax2.set_ylabel(r'$N_2 \;(g/L)$',color=colorlist[4],fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlim([0,8])
# make a plot with different y-axis using second axis object
#ax2.step(times[:-1],SFrate_val, color="red",linestyle='-')
#ax2.set_ylabel("Substrate Feed Rate" + r'$(g/l)$',color="red",fontsize=15)
#plt.xlim([0.0,4.0])
#plt.xticks(fontsize=12)
#plt.yticks(fontsize=12)
#plt.show()



"""

plt.figure(2,dpi=400)
plt.plot(times,predicted_list[1],'-s',color='k')
plt.plot(times,true_list[1],'o',markersize=marksize)
#plt.plot(times,predicted_minus[1],color='k',linestyle='--',alpha=0.7)
#plt.plot(times,predicted_plus[1],color='k',linestyle='--',alpha=0.7)
plt.fill_between(times.reshape(len(times),),predicted_minus[1].reshape(len(times),),
                 predicted_plus[1].reshape(len(times),),alpha=alphaval,color=colorlist[1])
plt.xlim([0,10])
plt.xlabel(r'$Time (hr)$', fontsize=15)
plt.ylabel(r'$C_1\,(g/L)$',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)




plt.figure(3,dpi=400)
plt.plot(times,predicted_list[2],color='k')
#plt.plot(times,true_list[2],'ko',markersize=marksize)
#plt.plot(times,predicted_minus[2],color='k',linestyle='--',alpha=0.7)
plt.plot(times,predicted_plus[2],color='k',linestyle='--',alpha=0.7)
plt.fill_between(times.reshape(len(times),),predicted_minus[2].reshape(len(times),),
                 predicted_plus[2].reshape(len(times),),alpha=alphaval,color=colorlist[2])
plt.xlim([0,10])
plt.xlabel(r'$Time (hr)$', fontsize=15)
plt.ylabel(r'$C_2 \,(g/L)$',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)




plt.figure(4,dpi=400)
plt.plot(times,predicted_list[3],color='k')
plt.plot(times,true_list[3],'ko',markersize=marksize)
#plt.plot(times,predicted_minus[3],color='k',linestyle='--',alpha=0.7)
#plt.plot(times,predicted_plus[3],color='k',linestyle='--',alpha=0.7)
plt.fill_between(times.reshape(len(times),),predicted_minus[3].reshape(len(times),),
                 predicted_plus[3].reshape(len(times),),alpha=alphaval,color=colorlist[3])
plt.xlim([0,10])
plt.xlabel(r'$Time (hr)$', fontsize=15)
plt.ylabel(r'$N_1 \,(Cells/L)$',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)



plt.figure(5,dpi=400)
plt.plot(times,predicted_list[4],color='k')
plt.plot(times,true_list[4],'ko',markersize=marksize)
plt.plot(times,predicted_minus[4],color='k',linestyle='--',alpha=0.7)
plt.plot(times,predicted_plus[4],color='k',linestyle='--',alpha=0.7)
plt.fill_between(times.reshape(len(times),),predicted_minus[4].reshape(len(times),),
                 predicted_plus[4].reshape(len(times),),alpha=alphaval,color=colorlist[4])
plt.xlim([0,10])
plt.xlabel(r'$Time (hr)$', fontsize=15)
plt.ylabel(r'$N_2 \,(Cells/L)$',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

"""
# Out:
# "\n\nplt.figure(2,dpi=400)\nplt.plot(times,predicted_list[1],'-s',color='k')\nplt.plot(times,true_list[1],'o',markersize=marksize)\n#plt.plot(times,predicted_minus[1],color='k',linestyle='--',alpha=0.7)\n#plt.plot(times,predicted_plus[1],color='k',linestyle='--',alpha=0.7)\nplt.fill_between(times.reshape(len(times),),predicted_minus[1].reshape(len(times),),\n                 predicted_plus[1].reshape(len(times),),alpha=alphaval,color=colorlist[1])\nplt.xlim([0,10])\nplt.xlabel(r'$Time (hr)$', fontsize=15)\nplt.ylabel(r'$C_1\\,(g/L)$',fontsize=15)\nplt.xticks(fontsize=15)\nplt.yticks(fontsize=15)\n\n\n\n\nplt.figure(3,dpi=400)\nplt.plot(times,predicted_list[2],color='k')\n#plt.plot(times,true_list[2],'ko',markersize=marksize)\n#plt.plot(times,predicted_minus[2],color='k',linestyle='--',alpha=0.7)\nplt.plot(times,predicted_plus[2],color='k',linestyle='--',alpha=0.7)\nplt.fill_between(times.reshape(len(times),),predicted_minus[2].reshape(len(times),),\n                 predicted_plus[2]
# ...

# %% [raw]
# fig,ax = plt.subplots(dpi=300)
# # make a plot
# ax.step(times[:-1],Drate_val, color="blue")
# # set x-axis label
# ax.set_xlabel(r'$Time (hr)$', fontsize=15)
# # set y-axis label
# ax.set_ylabel("Dilution Rate" + r'$(hr^{-1})$',color="blue",fontsize=15)
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)
# # twin object for two different y-axis on the sample plot
# ax2=ax.twinx()
# # make a plot with different y-axis using second axis object
# ax2.step(times[:-1],SFrate_val, color="red",linestyle='-')
# ax2.set_ylabel("Substrate Feed Rate" + r'$(g/l)$',color="red",fontsize=15)
# plt.xlim([0.0,4.0])
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)
# plt.show()
